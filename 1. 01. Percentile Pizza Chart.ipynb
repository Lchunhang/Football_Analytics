# %%
from urllib.request import urlopen
import matplotlib.pyplot as plt
from PIL import Image
from mplsoccer import PyPizza, add_image, FontManager
from highlight_text import fig_text

URL = "file:///C:/Users/user/Downloads/youngpic.png"
fdj_cropped = Image.open(urlopen(URL))

URL2 = "file:///C:/Users/user/Downloads/blue_bg_logo-removebg-preview.png"
fdj_cropped2 = Image.open(urlopen(URL2))

URL3 = "file:///C:/Football/FBRef.png"
fdj_cropped3 = Image.open(urlopen(URL3))

#file:///C:/Users/user/Downloads/youngpic.png

# %% [markdown]
# # Dashboard

# %%
# parameter list
params = ["Attacking Output", "Receptions in Penalty Box", "Shot Volume", 
          "Ball Retention", "Link-up Play Volume", "Ball-carrying Volume", "Progressive Passes",
          "Ball Recoveries", "Pressing Frequency", "Aerial Duels Quantity"]

# value list
values = [14, 15, 69, 54, 22, 42, 91, 71, 53, 10]

# color for the slices and text
slice_colors = ["#fd5901"] * 3 + ["#2a70ff"] * 4 + ["#00c631"] * 3
text_colors = ["#000000"] * 3 +  ["#000000"] * 4 + ["#000000"] * 3 


# instantiate PyPizza class
baker = PyPizza(
    params=params,                    # list of parameters
    background_color="black",         # background color 
    straight_line_color="#c2fdff",    # color for straight lines
    straight_line_lw=5,               # linewidth for straight lines
    last_circle_color="#c2fdff",      # color for last line
    last_circle_lw= 10,               # linewidth of last circle
    other_circle_lw=5,                # linewidth for other circles
    inner_circle_size=20              # size of inner circle
)

# plot pizza
fig, ax = baker.make_pizza(
    values,                          # list of values
    figsize=(15,12),                 # adjust the figsize according to your need
    color_blank_space="same",        # use the same color to fill blank space
    slice_colors=slice_colors,       # color for individual slices
    value_colors=text_colors,        # color for the value-text
    value_bck_colors=slice_colors,   # color for the blank spaces
    blank_alpha=0.4,                 # alpha for blank-space colors
    kwargs_slices=dict(
        edgecolor="#c2fdff", zorder=3, linewidth=5
    ),                               # values to be used when plotting slices
    kwargs_params=dict(
        color="black", fontsize=23,fontweight='bold', fontfamily='Courier New', va="center"
    ),                               # values to be used when adding parameter labels
    kwargs_values=dict(
        color="w", fontsize=35,fontweight='bold',
        fontfamily='Courier New', zorder=8,
        bbox=dict(
            edgecolor="#c2fdff", facecolor="#c2fdff",color='w',
            boxstyle="round,pad=0.2", lw=2
        )
    )                                
)

# add player image
ax_image = add_image(
    fdj_cropped, fig, left=0.45, bottom=0.432, width=0.12, height=0.15,zorder=-1
)

# add subtitle
fig.text(
    0.51, 1,
    "Ashley Young | 2022/23\n\n",
    size=50,
    ha="center", fontweight='bold', fontfamily='Courier New', color="yellow"
)

# add text
fig.text(
    0.12, 0.98, "Defending\n", size=45,
    fontweight='bold', fontfamily='Courier New', color="#00c631"
)

# add text
fig.text(
    0.39, 0.98, "Possession\n", size=45,
    fontweight='bold', fontfamily='Courier New', color="#1d9bf0"
)

# add text
fig.text(
    0.685, 0.98, "Attacking\n", size=45,
    fontweight='bold', fontfamily='Courier New', color="#fd5901"
)

#Adding the labels, to make it horizontal, customizable

# add label
fig.text(
    0.515, 0.9, "Attacking\nOutput", size=40, fontweight='bold', fontfamily='Courier New', color="w",ha='center'
)

# add label
fig.text(
    0.71, 0.81, "Receptions in\nPenalty Box", size=40, fontweight='bold', fontfamily='Courier New', color="w",ha='left'
)

# add label
fig.text(
    0.835, 0.6, "Shot\nVolume", size=40, fontweight='bold', fontfamily='Courier New', color="w",ha='left'
)

# add label
fig.text(
    0.835, 0.37, "Ball\nRetention", size=40, fontweight='bold', fontfamily='Courier New', color="w",ha='left'
)

# add label
fig.text(
    0.71, 0.12, "Link-up Play\nVolume", size=40, fontweight='bold', fontfamily='Courier New', color="w",ha='left'
)

# add label
fig.text(
    0.515, 0.025, "Ball-carrying\nVolume", size=40, fontweight='bold', fontfamily='Courier New', color="w",ha='center'
)

# add label
fig.text(
    0.31, 0.12, "Progressive\nPasses", size=40, fontweight='bold', fontfamily='Courier New', color="w",ha='right'
)

# add text
fig.text(
    0.19, 0.37, "Ball\nRecoveries", size=40, fontweight='bold', fontfamily='Courier New', color="w",ha='right'
)

# add label
fig.text(
    0.19, 0.6, "Pressing\nFrequency", size=40, fontweight='bold', fontfamily='Courier New', color="w",ha='right'
)

# add label
fig.text(
    0.31, 0.81, "Aerial Duels\nQuantity", size=40, fontweight='bold', fontfamily='Courier New', color="w",ha='right'
)

#Adding spacing required

# add space
fig.text(
    1, 1.2, "Space", size=20,
    fontweight='bold', fontfamily='Courier New', color="black"
)

# add space
fig.text(
   -0.05, 1.2, "Space", size=20,
    fontweight='bold', fontfamily='Courier New', color="black"
)

# add space
fig.text(
    0.5, 0.01, "Space", size=20,
    fontweight='bold', fontfamily='Courier New', color="black"
)

# add logo
ax_image = add_image(
    fdj_cropped2, fig, left=0.85, bottom=-0.05, width=0.2, height=0.2
)

plt.show()

# %% [markdown]
# # Comparison Pizza Charts

# %%
# parameter and values list
params = [
    'Post-Shot Expected Goals - Goals Allowed', 'Save Percentage (%)', 
    'Crosses Stopped (%)','Defensive Actions Outside Penalty Area', 
    'Launched Pass Completion (%)','Passes Attempted'
]
values   = [ -0.03, 69.0, 2.9, 0.93, 31.9, 26.00]  # player 1
values_2 = [  0.15, 79.5, 8.0, 1.19, 41.5, 29.72]  # player 2

# minimum range value and maximum range value for parameters
min_range = [ -0.52, 54.2, 0.90, 0.40, 22.5, 18.18]
max_range = [  0.31, 82.3, 12.7, 3.65, 52.2, 44.71]


# pass True in that parameter-index whose values are to be adjusted
# here True values are passed for "\nTouches\nper Turnover" and "pAdj\nPress Regains" params
params_offset = [
    False, False, False, False, False, True
]

# instantiate PyPizza class
baker = PyPizza(
    params=params,              # list of parameters
    min_range=min_range,        # min range values
    max_range=max_range,        # max range values
    background_color="black",   # background color 
    straight_line_color="w",    # color for straight lines
    straight_line_lw=2,         # linewidth for straight lines
    last_circle_color="w",      # color for last line
    last_circle_lw= 7,          # linewidth of last circle
    other_circle_lw=2           # linewidth for other circles    
)


# plot pizza
fig, ax = baker.make_pizza(
    values,                     # list of values
    compare_values=values_2,    # passing comparison values
    figsize=(15, 12),           # adjust figsize according to your need
    color_blank_space="same",   # use same color to fill blank space
    blank_alpha=0.4,            # alpha for blank-space colors
    param_location=110,         # where the parameters will be added
    kwargs_slices=dict(
        facecolor="#2a70ff", edgecolor="w",
        zorder=2, linewidth=3
    ),                          # values to be used when plotting slices
    kwargs_compare=dict(
        facecolor="#008140", edgecolor="w", zorder=4, linewidth=3,
    ),                          # values to be used when plotting comparison slices
    
    kwargs_params=dict(
        color="black", zorder=5,
        fontsize=17,fontweight='bold', fontfamily='Courier New', va="center"
    ),                          # values to be used when adding parameter
    kwargs_values=dict(
        color="w", fontsize=22,fontweight='bold',fontfamily='Courier New', zorder=3,
        bbox=dict(
            edgecolor="w", facecolor="#1A78CF",
            boxstyle="round,pad=0.2", lw=2
        )
    ),                           # values to be used when adding parameter-values
    kwargs_compare_values=dict(
        color="#000000", fontsize=22,fontweight='bold',fontfamily='Courier New', zorder=4,
        bbox=dict(
            edgecolor="#000000", facecolor="#008140",
            boxstyle="round,pad=0.2", lw=2
        )
    )                            # values to be used when adding comparison-values
)

# adjust text for comparison-values-text
baker.adjust_texts(params_offset, offset=0.35, adj_comp_values=True)

# add title
fig_text(
    0.5, 1.15, "<David de Gea> vs <Brice Samba>",
     fig=fig,
    highlight_textprops=[{"color": '#5388f5'}, {"color": '#008140'}],
    ha="center", fontsize=50, fontweight='bold', fontfamily='Courier New',color="#F2F2F2"
)

# add space
fig.text(
    0.5, 1.2, "Space", size=20,
    fontweight='bold', fontfamily='Courier New', color="black"
)

# add space
fig.text(
    0.01, 1.2, "Space", size=20,
    fontweight='bold', fontfamily='Courier New', color="black"
)

# add space
fig.text(
    0.95, 1.2, "Space", size=20,
    fontweight='bold', fontfamily='Courier New', color="black"
)

# add space
fig.text(
    0.65, -0.04, "Note: All Stats are per 90", size=25,
    fontweight='bold', fontfamily='Courier New', color="w"
)


#Adding the labels, to make it horizontal, customizable

# add label
fig.text(
    0.5, 0.91, "Post-Shot Expected Goals\n-\nGoals Allowed (PSxG-GA)", size=30, fontweight='bold', fontfamily='Courier New', color="w",ha='center'
)

# add label
fig.text(
    0.76, 0.75, "Save\nPercentage (%)", size=30, fontweight='bold', fontfamily='Courier New', color="w",ha='left'
)

# add label
fig.text(
    0.76, 0.21, "Crosses\nStopped (%)", size=30, fontweight='bold', fontfamily='Courier New', color="w",ha='left'
)

fig.text(
    0.51, 0.04, "Defensive Actions\nOutside Penalty Area", size=30, fontweight='bold', fontfamily='Courier New', color="w",ha='center'
)

# add label
fig.text(
    0.26, 0.21, "Launched Pass\nCompletion (%)", size=30, fontweight='bold', fontfamily='Courier New', color="w",ha='right'
)

# add label
fig.text(
    0.26, 0.75, "Passes\nAttempted", size=30, fontweight='bold', fontfamily='Courier New', color="w",ha='right'
)

plt.show()

# %% [markdown]
# # Tableau

# %%
# parameter list
params = ["Expected\nOutput","Shot-Creating\nActions","Dribbling\nThreat", 
          "Progressive\nActions", "Possession\nDirectness", "Possession\nSecurity",
          "Possession\nRegain", "Pressing\nFrequency", "Ball Winning\nAbilities"]

# value list
# The values are taken from the excellent fbref website (supplied by StatsBomb)
values = [63,89,67,83,74,83,33,85,43]

# color for the slices and text
slice_colors = ["crimson"] * 3 + ["#fbcf00"] * 3 + ["#edece9"] * 3
text_colors = ["#000000"] * 3 +  ["#000000"] * 3 + ["#000000"] * 3 



# instantiate PyPizza class
baker = PyPizza(
    params=params,                    # list of parameters
    background_color="#171c38",       # background color 
    straight_line_color="#000000",    # color for straight lines
    straight_line_lw=2.5,             # linewidth for straight lines
    last_circle_color="#000000",      # color for last line
    last_circle_lw= 5,                 # linewidth of last circle
    other_circle_lw=0,                # linewidth for other circles
    inner_circle_size=0             # size of inner circle
)

# plot pizza
fig, ax = baker.make_pizza(
    values,                          # list of values
    figsize=(8,9.5),                 # adjust the figsize according to your need
    color_blank_space="same",        # use the same color to fill blank space
    slice_colors=slice_colors,       # color for individual slices
    value_colors=text_colors,        # color for the value-text
    value_bck_colors=slice_colors,   # color for the blank spaces
    blank_alpha=0.4,                 # alpha for blank-space colors
    kwargs_slices=dict(
        edgecolor="#000000", zorder=2, linewidth=3
    ),                               # values to be used when plotting slices
    kwargs_params=dict(
        color="w", fontsize=12,fontweight='bold',
        fontfamily='Courier New', va="center"
    ),                               # values to be used when adding parameter labels
    kwargs_values=dict(
        color="#000000", fontsize=13,fontweight='bold',
        fontfamily='Courier New', zorder=3,
        bbox=dict(
            edgecolor="#000000", facecolor="cornflowerblue",
            boxstyle="round,pad=0.2", lw=2
        )
    )                                # values to be used when adding parameter-values labels
)

# add text
fig.text(
    0.18, 0.902, "Defending              Possession             Attacking", size=12,
    fontweight='bold', fontfamily='Courier New', color="w"
)

# add rectangles
fig.patches.extend([
    plt.Rectangle(
        (0.15, 0.90), 0.025, 0.021, fill=True, color="#FBFBFB",
        transform=fig.transFigure, figure=fig
    ),
    plt.Rectangle(
        (0.44, 0.90), 0.025, 0.021, fill=True, color="#fbcf00",
        transform=fig.transFigure, figure=fig
    ),
    plt.Rectangle(
        (0.727, 0.90), 0.025, 0.021, fill=True, color="crimson",
        transform=fig.transFigure, figure=fig,
    ),
])

plt.show()

# %% [markdown]
# # Breakdown of Stats Percentile

# %%
# parameter list
params = ["npxG","Successful\nAttacking Actions","Shot-Creating\nActions",
          "Offensive\nDuels Won","Dribble\nCompletions(%)","\nCarries into\nFinal Third &\nPenalty Area",
          "xA","\nPasses into\nFinal Third &\nPenalty Area","Key\nPasses",
          "Tackles","Successful\nPressures","PAdj\nInterceptions"]

# value list
# The values are taken from the excellent fbref website (supplied by StatsBomb)
values = [97,93,80,
          93,36,96,
          89,54,71,
          25,20,12]

# color for the slices and text
slice_colors = ["crimson"] * 3 + ["#fd5901"] * 3 + ["#fbcf00"] * 3 + ["#edece9"] * 3
text_colors = ["#000000"] * 3 +  ["#000000"] * 3 + ["#000000"] * 3 + ["#000000"] * 3 



# instantiate PyPizza class
baker = PyPizza(
    params=params,                    # list of parameters
    background_color="#1266AB",       # background color 
    straight_line_color="#000000",    # color for straight lines
    straight_line_lw=2.5,             # linewidth for straight lines
    last_circle_color="#000000",      # color for last line
    last_circle_lw= 5,                # linewidth of last circle
    other_circle_lw=0,                # linewidth for other circles
    inner_circle_size=20              # size of inner circle
)

# plot pizza
fig, ax = baker.make_pizza(
    values,                          # list of values
    figsize=(8,9.5),                 # adjust the figsize according to your need
    color_blank_space="same",        # use the same color to fill blank space
    slice_colors=slice_colors,       # color for individual slices
    value_colors=text_colors,        # color for the value-text
    value_bck_colors=slice_colors,   # color for the blank spaces
    blank_alpha=0.4,                 # alpha for blank-space colors
    kwargs_slices=dict(
        edgecolor="#000000", zorder=2, linewidth=3
    ),                               # values to be used when plotting slices
    kwargs_params=dict(
        color="w", fontsize=12,fontweight='bold', fontfamily='Courier New', va="center"
    ),                               # values to be used when adding parameter labels
    kwargs_values=dict(
        color="#000000", fontsize=13,fontweight='bold',
        fontfamily='Courier New', zorder=3,
        bbox=dict(
            edgecolor="#000000", facecolor="cornflowerblue",
            boxstyle="round,pad=0.2", lw=2
        )
    )                                # values to be used when adding parameter-values labels
)

# add subtitle
fig.text(
    0.515, 0.895,
    "Percentile Rank vs Ligue 1 Midfielders | 2021/22",
    size=19,
    ha="center", fontweight='bold', fontfamily='Courier New', color="#F2F2F2"
)


# add title
fig.text(
    0.515, 0.9, "Houssem Aouar - 23, Lyon\n", size=30,
    ha="center", fontweight='bold', fontfamily='Courier New', color="#F2F2F2"
)


# add credits
CREDIT_1 = "Made by: @chunhang7\nData: Statsbomb via FBRef & Wyscout"
CREDIT_3 = "All values adjusted for possession and playing time"
CREDIT_2 = "Inspired by: @exceedingxpuns, @Worville, @FootballSlices, @somazerofc & @Soumyaj15209314"


fig.text(
    0.985, 0.055, f"{CREDIT_1}\n{CREDIT_2}", size=10,
    fontweight='bold',
        fontfamily='Courier New', color="#F2F2F2", ha="right"
)

"""# add text
fig.text(
    0.18, 0.902, "Defending              Possession              Attacking", size=12,
    fontweight='bold', fontfamily='Courier New', color="w"
)


# add rectangles
fig.patches.extend([
    plt.Rectangle(
        (0.15, 0.90), 0.025, 0.021, fill=True, color="#FBFBFB",
        transform=fig.transFigure, figure=fig
    ),
    plt.Rectangle(
        (0.44, 0.90), 0.025, 0.021, fill=True, color="#fbcf00",
        transform=fig.transFigure, figure=fig
    ),
    plt.Rectangle(
        (0.74, 0.90), 0.025, 0.021, fill=True, color="crimson",
        transform=fig.transFigure, figure=fig,
    ),
])

"""
# add image
ax_image = add_image(
    fdj_cropped, fig, left=0.4478, bottom=0.43, width=0.130, height=0.145
)   # these values might differ when you are plotting

plt.show()

# %%
# parameter list
params = [
    "Expected\nAssists", "Second\nAssist", "Shot\nAssists", 
    "Key\nPasses","Passes To\n Final Third","Passes To\n Penalty Area"
]

# values for corresponding parameters
# The values are taken from the excellent fbref website (supplied by StatsBomb)
values = [58,2,47,42,17,85]

# instantiate PyPizza class
baker = PyPizza(
    params=params,                  # list of parameters
    background_color="#1266AB",     # background color
    straight_line_color="black",    # color for straight lines
    straight_line_lw=4,             # linewidth for straight lines
    last_circle_lw=8,               # linewidth of last circle
    last_circle_color = "black",
    other_circle_lw=2,              # linewidth for other circles
    other_circle_color = "w",
    other_circle_ls="-."            # linestyle for other circles
)

# plot pizza
fig, ax = baker.make_pizza(
    values,              # list of values
    figsize=(13, 8),      # adjust figsize according to your need
    param_location=110,  # where the parameters will be added
    kwargs_slices=dict(
        facecolor="#edece9", edgecolor="black",
        zorder=2, linewidth=4
    ),                   # values to be used when plotting slices
    kwargs_params=dict(
        color="white", fontsize=17,
        fontweight='bold',fontfamily='Courier New', va="center"
    ),                   # values to be used when adding parameter
    kwargs_values=dict(
        color="black", fontsize=17,
        fontweight='bold',fontfamily='Courier New', zorder=3,
        bbox=dict(
            edgecolor="black", facecolor="white",
            boxstyle="round,pad=0.2", lw=2
        )
    )                    # values to be used when adding parameter-values
)

# add title
fig_text(
     1, 1.15, "Player Name",
     fig=fig, ha="center", fontsize=50, fontweight='bold', fontfamily='Courier New',color="#F2F2F2"
)



plt.show()
